# %% [markdown]
# from opensky_api import OpenSkyApi
# api = OpenSkyApi()
# api = OpenSkyApi("Tofi1115","becsuv-8cohTa-meqsaw")

# %% [markdown]
# states = api.get_states(time_secs=0,bbox=(37, 41, -109, -102)) #45.8389, 47.8229, 5.9962, 10.5226
# for s in states.states:
#     print("(%r, %r, %r, %r)" % (s.longitude, s.latitude, s.baro_altitude, s.velocity))

# %%
import pyopensky

# %%
from pyopensky.config import opensky_config_dir

print(opensky_config_dir)
# Out:
# /Users/katlingarula/Library/Application Support/pyopensky

# %%
from pyopensky.trino import Trino

# %%
from pyopensky import trino
trino = pyopensky.trino.Trino()

# %% [markdown]
# user="tofi1115", password="becsuv-8cohTa-meqsaw", clientId="tofi1115-api-client",clientSecret="Xalyfwcg5U2XYwGlqYXIbk1QJHfkwM7b"

# %%
# Get a list of flights within a specific time range and optional filters
flights_df = trino.flightlist(
    start="2023-02-01 09:00:00", 
    stop="2023-02-01 9:15:00",
    airport="KDEN",
    cached=False
)

print(flights_df.head())
# Out:
# FINISHED: : 0.00% [00:00, ?%/s]
# DOWNLOAD: 2.00lines [00:00, 82.0lines/s]
#    icao24                  firstseen departure                   lastseen  \
# 0  aa6103  2023-02-01 07:00:18+00:00      KSFO  2023-02-01 09:05:47+00:00
# 1  a35283  2023-02-01 06:27:19+00:00      KDEN  2023-02-01 09:11:54+00:00
#
#   arrival callsign                        day
# 0    KDEN  UAL8143  2023-02-01 00:00:00+00:00
# 1    KTPA   FFT738  2023-02-01 00:00:00+00:00

# %%
flight_list_df = trino.history(
    start="2023-01-01 09:00:00", 
    stop="2023-01-01 9:15:00", 
    airport="KDEN",
    cached=False
)
# Out:
# FINISHED: : 100% [00:05, 19.3%/s]
# DOWNLOAD: 10.2klines [00:00, 146klines/s]

# %%
flight_list_df.head()
# Out:
#                         time  icao24        lat        lon    velocity  \
# 0  2023-01-01 09:00:01+00:00  a254d8  49.628632 -64.837406  302.657947
# 1  2023-01-01 09:00:02+00:00  a254d8  49.631058 -64.824612  302.657947
# 2  2023-01-01 09:00:03+00:00  a254d8  49.631836 -64.820565  302.657947
# 3  2023-01-01 09:00:04+00:00  a254d8  49.632248 -64.818179  302.657947
# 4  2023-01-01 09:00:05+00:00  a254d8  49.633111 -64.813769  302.657947
#
#      heading  vertrate callsign onground  alert    spi squawk  baroaltitude  \
# 0  73.813811  -0.32512    UAL27    False  False  False   1423       11277.6
# 1  73.813811  -0.32512    UAL27    False  False  False   1423       11277.6
# 2  73.813811  -0.32512    UAL27    False  False  False   1423       11277.6
# 3  73.813811  -0.32512    UAL27    False  False  False   1423       11277.6
# 4  73.813811  -0.32512    UAL27    False  False  False   1423       11277.6
#
#    geoaltitude   lastposupdate     lastcontact        serials  \
# 0     11079.48  1672563598.587  1672563600.823  [-1408237154]
# 1     11079.48   1672563601.75   1672563601.75  [-1408237154]
# 2     11079.48  1672563602.899  1672563602.899  [-1408237154]
# 3     11079.48  1672563603.513  1672563603.913  [-1408237154]
# 4     11079.48  1672563604.531  1672563604.531  [-1408237154]
#
#                         hour
# 0  2023-01-01 09:00:00+00:00
# 1  2023-01-01 09:00:00+00:00
# 2  2023-01-01 09:00:00+00:00
# 3  2023-01-01 09:00:00+00:00
# 4  2023-01-01 09:00:00+00:00

# %%
flight_list_df = trino.history(
    start="2025-01-01 10:00:00", 
    stop="2025-01-01 11:00:00", 
    bounds=(-109, 37, -103, 41),#bounds=(106,37,103, 50), #West south east north
    cached=False
)
flight_list_df.head()
# Out:
# FINISHED: : 100% [00:11, 8.53%/s]
# DOWNLOAD: 26.2klines [00:00, 66.0klines/s]
#                         time  icao24        lat         lon    velocity  \
# 0  2025-01-01 10:30:03+00:00  ab2824  39.317642 -108.998884  251.287332
# 1  2025-01-01 10:30:04+00:00  ab2824   39.31788 -108.995728  251.287332
# 2  2025-01-01 10:30:05+00:00  ab2824  39.318008 -108.994227  251.287332
# 3  2025-01-01 10:30:06+00:00  ab2824  39.318237 -108.991361  251.287332
# 4  2025-01-01 10:30:07+00:00  ab2824  39.318439  -108.98877  251.287332
#
#      heading  vertrate callsign onground  alert    spi squawk  baroaltitude  \
# 0  84.242721   0.65024   N818LX    False  False  False   <NA>      10675.62
# 1  84.242721   2.60096   N818LX    False  False  False   <NA>      10675.62
# 2  84.242721  -0.32512   N818LX    False  False  False   <NA>      10675.62
# 3  84.242721  -1.95072   N818LX    False  False  False   <NA>      10675.62
# 4  84.242721  -0.65024   N818LX    False  False  False   <NA>      10675.62
#
#    geoaltitude   lastposupdate     lastcontact                     serials  \
# 0      10629.9  1735727402.901  1735727402.998  [-1408231766, -1408229603]
# 1      10629.9  1735727403.992  1735727403.992  [-1408231766, -1408229603]
# 2      10629.9  1735727404.539  1735727404.539  [-1408231766, -1408229603]
# 3     10637.52  1735727405.562  1735727405.626  [-1408231766, -1408229603]
# 4      10629.9  1735727406.744  1735727406.744  [-1408231766, -1408229603]
#
#                         hour
# 0  2025-01-01 10:00:00+00:00
# 1  2025-01-01 10:00:00+00:00
# 2  2025-01-01 10:00:00+00:00
# 3  2025-01-01 10:00:00+00:00
# 4  2025-01-01 10:00:00+00:00

# %%
from pyopensky.config import opensky_config_dir

print(opensky_config_dir)
# Out:
# /Users/katlingarula/Library/Application Support/pyopensky

# %%
from sqlalchemy import select
from pyopensky.schema import StateVectorsData4, FlightsData4
from pyopensky.trino import Trino

# %%
trino = Trino()

# Select specific columns
query = (
    select(StateVectorsData4)
    .with_only_columns(
        StateVectorsData4.time,
        StateVectorsData4.icao24,
        StateVectorsData4.lat,
        StateVectorsData4.lon,
        StateVectorsData4.baroaltitude,
        StateVectorsData4.callsign,
    )
    .where(StateVectorsData4.callsign.startswith("AFR"))
    .where(StateVectorsData4.hour >= "2023-01-01")
    .where(StateVectorsData4.hour < "2023-01-02")
    .limit(1000)
)

df = trino.query(query)
# Out:
# FINISHED: : 48.5% [00:00, 126%/s]
# DOWNLOAD: 1.00klines [00:00, 67.7klines/s]

# %%
from pyopensky.trino import Trino

trino = Trino()

# Download data within geographic bounds (west, south, east, north)
df = trino.history(
    start="2023-07-01",
    stop="2023-07-02",
    bounds=(1.06, 43.38, 1.74, 43.85),  # Toulouse area
    StateVectorsData4.baroaltitude < 3048  # Below 10,000 ft
)
# Out:
#   Cell In[20], line 11
#     )
#     ^
# SyntaxError: positional argument follows keyword argument
