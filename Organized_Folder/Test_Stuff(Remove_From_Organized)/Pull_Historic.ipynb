# %% [markdown]
# from opensky_api import OpenSkyApi
# api = OpenSkyApi()
# api = OpenSkyApi("Tofi1115","becsuv-8cohTa-meqsaw")

# %% [markdown]
# states = api.get_states(time_secs=0,bbox=(37, 41, -109, -102)) #45.8389, 47.8229, 5.9962, 10.5226
# for s in states.states:
#     print("(%r, %r, %r, %r)" % (s.longitude, s.latitude, s.baro_altitude, s.velocity))

# %%
import pyopensky

# %%
from pyopensky.config import opensky_config_dir

print(opensky_config_dir)
# Out:
# /Users/katlingarula/Library/Application Support/pyopensky

# %%
from pyopensky import trino
trino = pyopensky.trino.Trino(user="tofi1115-api-client", password="AsJbA55QWgcas5HuwFswsK5D14tZypqJ")

# %%
#pyopensky=Trino()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 pyopensky=Trino()
#
# NameError: name 'Trino' is not defined

# %%
# Get a list of flights within a specific time range and optional filters
flights_df = trino.flightlist(
    start="2023-01-01 09:00:00",
    stop="2023-01-01 12:00:00",
    arrival_airport="RJBB",   # ICAO airport identifier
    departure_airport="LFBO"
)

print(flights_df.head())
# Out:
# Authentication failing on trino
# Open the following URL in browser for the external authentication:
# https://trino.opensky-network.org/oauth2/token/initiate/840ed2910182b65414637ddcf7e00f1119938545295bf4a91069b28599d25d43
# ---------------------------------------------------------------------------
# TrinoUserError                            Traceback (most recent call last)
# File /opt/anaconda3/envs/traffic/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1961, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1960     if not evt_handled:
# -> 1961         self.dialect.do_execute(
#    1962             cursor, str_statement, effective_parameters, context
#    1963         )
#    1965 if self._has_events or self.engine._has_events:
#
# File /opt/anaconda3/envs/traffic/lib/python3.10/site-packages/trino/sqlalchemy/dialect.py:442, in TrinoDialect.do_execute(self, cursor, statement, parameters, context)
#     439 def do_execute(
# ...

# %%
from pyopensky.config import opensky_config_dir

print(opensky_config_dir)
# Out:
# /Users/katlingarula/Library/Application Support/pyopensky
