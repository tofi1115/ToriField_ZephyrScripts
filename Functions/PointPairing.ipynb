# %%
def point_pairing(pointlist1,pointlist2):

# %% [markdown]
# pointlist will be a list
# each point in the list will be a tuple
# I think that it would be easiest to just

# %%
list1=[(0,1),(5,4)]
list2=[(0,0),(4,4)]

# %%
point_pairing(list1,list2)
