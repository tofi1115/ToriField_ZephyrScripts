# %%
import pyopensky
import trino

# %%
boulder_lat=40.0190
boulder_lon=-105.2747

parker_lat=39.5186
parker_lon=-104.7614

# %%
pyopensky.trino.history(start=1751386544, stop=1751390144) #,bounds=(parker_lat, boulder_lat, boulder_lon, parker_lon))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 pyopensky.trino.history(start=1751386544, stop=1751390144) #,bounds=(parker_lat, boulder_lat, boulder_lon, parker_lon))
#
# AttributeError: module 'pyopensky' has no attribute 'trino'

# %%
pyopensky.trino_python_client()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 pyopensky.trino_python_client()
#
# AttributeError: module 'pyopensky' has no attribute 'trino_python_client'
